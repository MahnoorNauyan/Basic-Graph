# %%
import networkx as nx

# %%
nodes = ["1", "2", "3", "4", "5", "6","7"]

edges = [("1", "2"),
        ("2", "3"),
        ("3", "3"),
        ("3", "4"),
        ("1", "4"),
        ("1", "6"),
        ("5", "2"),
        ("6","7"),
         ("7","7")]

# %%
G=nx.Graph()

# %%
G.add_nodes_from(nodes)
G.add_edges_from(edges)

# %%
nx.draw_planar(G, with_labels = True, font_color="whitesmoke", font_size=10,)

# %%
nx.draw_kamada_kawai(G, with_labels = True, font_color="whitesmoke", font_size=10,)

# %%
print(f"radius: {nx.radius(G)}")
print(f"diameter: {nx.diameter(G)}")
print(f"eccentricity: {nx.eccentricity(G)}")
print(f"center: {nx.center(G)}")
print(f"periphery: {nx.periphery(G)}")
print(f"density: {nx.density(G)}")
print(f"degree: {nx.degree(G)}")
# Out:
# radius: 2
# diameter: 4
# eccentricity: {'1': 2, '2': 3, '3': 4, '4': 3, '5': 4, '6': 3, '7': 4}
# center: ['1']
# periphery: ['3', '5', '7']
# density: 0.42857142857142855
# degree: [('1', 3), ('2', 3), ('3', 4), ('4', 2), ('5', 1), ('6', 2), ('7', 3)]
